# %%
tables = """adherence_scores
adj_neo_tx
cancer_diagnosis
claim
claim_care_team
claim_payer
claim_payer_med_mapping
claim_procedure
claim_provider_npi_summary
disease_era
lot
metastatic_sites
patient_status
pharmacy_claim_payment
progression_era
radiation_era
treatment_era
visit_occurrence"""

# %%
table_to_copy = sorted(tables.split("\n"))

# %%
table_to_copy
# Out:
# ['adherence_scores',
#  'adj_neo_tx',
#  'cancer_diagnosis',
#  'claim',
#  'claim_care_team',
#  'claim_payer',
#  'claim_payer_med_mapping',
#  'claim_procedure',
#  'claim_provider_npi_summary',
#  'disease_era',
#  'lot',
#  'metastatic_sites',
#  'patient_status',
#  'pharmacy_claim_payment',
#  'progression_era',
#  'radiation_era',
#  'treatment_era',
#  'visit_occurrence']

# %%
for i in table_to_copy:
    print(f"--{i}\nDROP TABLE IF EXISTS c3_precision_commercial_20260227_demo.{i};\nSELECT * INTO c3_precision_commercial_20260227_demo.{i} FROM c3_precision_commercial_20260227.{i};\n\n")
# Out:
# --adherence_scores
# DROP TABLE IF EXISTS c3_precision_commercial_20260227_demo.adherence_scores;
# SELECT * INTO c3_precision_commercial_20260227_demo.adherence_scores FROM c3_precision_commercial_20260227.adherence_scores;
#
#
# --adj_neo_tx
# DROP TABLE IF EXISTS c3_precision_commercial_20260227_demo.adj_neo_tx;
# SELECT * INTO c3_precision_commercial_20260227_demo.adj_neo_tx FROM c3_precision_commercial_20260227.adj_neo_tx;
#
#
# --cancer_diagnosis
# DROP TABLE IF EXISTS c3_precision_commercial_20260227_demo.cancer_diagnosis;
# SELECT * INTO c3_precision_commercial_20260227_demo.cancer_diagnosis FROM c3_precision_commercial_20260227.cancer_diagnosis;
#
#
# --claim
# DROP TABLE IF EXISTS c3_precision_commercial_20260227_demo.claim;
# SELECT * INTO c3_precision_commercial_20260227_demo.claim FROM c3_precision_commercial_20260227.claim;
#
#
# --claim_care_team
# DROP TABLE IF EXISTS c3_precision_commercial_20260227_demo.claim_care_team;
# ...
