# %%
from scipy.special import result

#While loop

#Designing a password entry system

password = "Hello"
passw = input("Enter your password: ")
while password != passw:
    passw = input("Enter a correct password: ")
print("Logged in successful!")
# Out:
# Logged in successful!

# %%
password = "Hello"
passw = input("Enter your password: ")
while True:
    passw = input("Enter a correct password: ")
    if password == passw:
        break
print("Logged in successful!")
# Out:
# Logged in successful!

# %% [markdown]
# ***Question-1 Find the sum of first 10 numbers using `while` loop***

# %%
n = 0
m = 10
s = 0
while m > n:
    s+= n
    n +=1
print("The sum of {a} is {b}!".format(a=m, b=s))
# Out:
# The sum of 10 is 45!

# %% [markdown]
# ***Question-2 Write a function to check if number is prime***

# %%
def is_prime(n):
    if n < 2:
        return False
    else:
        for i in range(2,int(n**0.5)+1):
            if n % i == 0:
                return False
        else:
            return True

# %%
is_prime(87)
# Out:
# False

# %%
data = [(i,is_prime(i)) for i in l]

# %%
result = map(is_prime,l)

# %%
for i in result:
    print(i)
# Out:
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
result2 = filter(is_prime,l)

# %%
for i in result2:
    print(i)
# Out:
# 3

# %% [markdown]
# ***Higher Order Function (HoF)***
# - map
# - filter
# - reduce

# %% [markdown]
# 1. Map

# %%
nums = [10,15,20,25,30]

# %%
result = map(lambda x:x*2,nums)

# %%
print(list(result))
# Out:
# [20, 30, 40, 50, 60]

# %%
names = ["Gopi","Anupam","Aahana","Subha","Dip"]

# %%
def get_length(x):
    return len(x)

# %%
sorted(names, key=get_length, reverse=True)
# Out:
# ['Anupam', 'Aahana', 'Subha', 'Gopi', 'Dip']

# %%
def get_length(x):
    return -len(x)

# %%
sorted(names, key=get_length, reverse=True)
# Out:
# ['Dip', 'Gopi', 'Subha', 'Anupam', 'Aahana']

# %%
marks = [[56,30,60],[90,80,60],[70,60,100]]

# %%
sorted(marks, key=lambda x:-sum(x))
# Out:
# [[90, 80, 60], [70, 60, 100], [56, 30, 60]]

# %%
#Filter
nums = [33,45,66,78,99,33,24,56,23,13]

# %%
list(filter(lambda x:x%2 == 0,nums))
# Out:
# [66, 78, 24, 56]

# %%
is

# %%
list(filter(is_prime,nums))
# Out:
# [23, 13]

# %%
from functools import reduce

# %%
reduce(lambda x,y:x+y, nums)
# Out:
# 470

# %%
reduce(lambda x,y:x*y, nums)
# Out:
# 10036553025058560

# %%
nums2 = [33,45,66,78,99,33,24,56,23,13]

# %%
reduce(lambda x,y: x if x>y else y,nums2)
# Out:
# 99

# %%
reduce(lambda x,y: x if x<y else y,nums2)
# Out:
# 13

# %%
(lambda x,y: x if x<y else y)(25,600)
# Out:
# 25

# %%
(lambda x,y: x if x>y else y)(25,600)
# Out:
# 600

# %%
import random
l = [random.randint(3,56) for i in range(11)]

# %%
def get_srqt_sum(n):
    return n**2

# %%
from functools import reduce

# %%
sm = 0

for i in l:
    sm += i**2
    
print(sm)
# Out:
# 9033

# %%
reduce(lambda x, y: x + y**2, l, 0)
# Out:
# 9033

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.dropna(subset=["embark_town"], inplace=True)

# %%
titanic['city_length'] = titanic["embark_town"].apply(lambda x: len(x))

# %%
titanic[["embark_town","city_length"]]
# Out:
#      embark_town  city_length
# 0    Southampton           11
# 1      Cherbourg            9
# 2    Southampton           11
# 3    Southampton           11
# 4    Southampton           11
# ..           ...          ...
# 886  Southampton           11
# 887  Southampton           11
# 888  Southampton           11
# 889    Cherbourg            9
# 890   Queenstown           10
#
# [889 rows x 2 columns]
